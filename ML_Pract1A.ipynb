# %% [markdown]
# <a href="https://colab.research.google.com/github/aayan-mk/AvRak/blob/main/ML_Pract1A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data= { 'Name':[ 'Aayan','Avaish', 'Aniket', 'Nabil'],
 'Age': [21, 21, 22, np.nan],
 'Marks': [ np.nan, 90, 90, 90],
 'City': [ 'Mumbai', 'Pune', 'Bangalore', np.nan] }
df= pd.DataFrame(data)
df.head()
# Out:
#      Name   Age  Marks       City
# 0   Aayan  21.0    NaN     Mumbai
# 1  Avaish  21.0   90.0       Pune
# 2  Aniket  22.0   90.0  Bangalore
# 3   Nabil   NaN   90.0        NaN

# %%
df_drop=df.dropna()
df_drop.head()
# Out:
#      Name   Age  Marks       City
# 1  Avaish  21.0   90.0       Pune
# 2  Aniket  22.0   90.0  Bangalore

# %%
df_ffill=df.fillna(method='ffill')
df_ffill.head()
df_bfill=df.fillna(method='bfill')
df_bfill.head()
# Out:
# /tmp/ipython-input-3350440358.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill=df.fillna(method='ffill')
# /tmp/ipython-input-3350440358.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill=df.fillna(method='bfill')
#      Name   Age  Marks       City
# 0   Aayan  21.0   90.0     Mumbai
# 1  Avaish  21.0   90.0       Pune
# 2  Aniket  22.0   90.0  Bangalore
# 3   Nabil   NaN   90.0        NaN

# %%
df_ffill=df.fillna(method='ffill')
df_ffill.head()
# Out:
# /tmp/ipython-input-3865171801.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill=df.fillna(method='ffill')
#      Name   Age  Marks       City
# 0   Aayan  21.0    NaN     Mumbai
# 1  Avaish  21.0   90.0       Pune
# 2  Aniket  22.0   90.0  Bangalore
# 3   Nabil  22.0   90.0  Bangalore

# %%
df_bfill=df.fillna(method='bfill')
df_bfill.head()
# Out:
# /tmp/ipython-input-208522624.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill=df.fillna(method='bfill')
#      Name   Age  Marks       City
# 0   Aayan  21.0   90.0     Mumbai
# 1  Avaish  21.0   90.0       Pune
# 2  Aniket  22.0   90.0  Bangalore
# 3   Nabil   NaN   90.0        NaN

# %%
df['Age'] = df['Age'].interpolate().ffill()
df['Marks'] = df['Marks'].interpolate().ffill()
df['City'] = df['City'].interpolate().ffill()
df.head(10)
# Out:
# /tmp/ipython-input-558161374.py:3: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df['City'] = df['City'].interpolate().ffill()
#      Name   Age  Marks       City
# 0   Aayan  21.0    NaN     Mumbai
# 1  Avaish  21.0   90.0       Pune
# 2  Aniket  22.0   90.0  Bangalore
# 3   Nabil  22.0   90.0  Bangalore
